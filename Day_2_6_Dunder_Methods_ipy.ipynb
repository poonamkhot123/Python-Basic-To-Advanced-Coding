# %% [markdown]
# <a href="https://colab.research.google.com/github/poonamkhot123/Python-Basic-To-Advanced-Coding/blob/main/Day_2_6_Dunder_Methods_ipy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Introduction to dunder methods.

# %%
# __init__
# __str__
# __repr__
# __li__
# __add__
# __len__
# __call__

# %%
class Point:
  def __init__(self,x,y):
    self.x = x
    self.y = y

p = Point(3,4)
print(p)

# %%
class Point:
  def __init__(self,x,y):
    self.x = x
    self.y=y
  def __str__(self):
    return f"Point({self.x},{self.y})"

  def __repr__(self):
    return f"Point(x={self.x},y={self.y})"

# %%
p1 = Point(3,4)
p2 = Point(65,11)

# %%
class Money:
  def __init__(self,amount):
    self.amount = amount
  def __eq__(self,other):
    return self.amount == other.amount

  def __lt__(self,other):
    return self.amount < other.amount

a = Money(80)
b = Money(100)

print(a>b)
print(a<b)
# Out:
# False
# True

# %%
print (a ==b )
# Out:
# False

# %%
class Distance:
  def __init__(self,km):
    self.km = km

  def __add__(self,other):
    return self.km + other.km

  def __sub__(self,other):
    return Distance(self.km - other.km)

  def __mul__(self,times):
    return Distance(self.km*times)

  def __str__(self):
    return f"{self.km} km"

d1 = Distance(10)
d2 = Distance(20)

print(d1+d2)
# Out:
# 30

# %%
print(d1 + d2)
# Out:
# 30

# %%
print(d1 *3)
# Out:
# 30 km

# %%
print(d1 - d2)
# Out:
# -10 km

# %%
print(d2-d1)
# Out:
# 10 km
