# %% [markdown]
# <a href="https://colab.research.google.com/github/poonamkhot123/Python-Basic-To-Advanced-Coding/blob/main/Day_2_8_Exception_handling_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  age = int(input("Enter your age:"))
  print(f"You will be {age +1} next year")
except ValueError:
  print("Please enter a valid number.")
# Out:
# Enter your age:56
# You will be 57 next year

# %%
try:
  age = int(input("ENter your age:"))
  print(f"You will be {age + 1} next year")
except ValueError:
  print("please enter a valid number.")
# Out:
# ENter your age:hj
# please enter a valid number.

# %%
try:
  age = int(input("Enter a age:"))
  if age >= 18:
    print("adult")
  else:
    print("not adult")
except:
  print("some error occured")
# Out:
# Enter a age:rt
# some error occured

# %%
try:
  num1 = int(input("Enter number 1:"))
  num2 = int(input("Enter number 2:"))
  print(f"num1/num2 = {num1/num2}")
except:
  print("some error occurred")
# Out:
# Enter number 1:56
# Enter number 2:0
# some error occurred

# %%
try:
  num1 = int(input("Enter number 1:"))
  num2 = int(input("Enter number 2:"))
  print(f"num1/num2 = {num1/num2}")
except ZeroDivisionError:
  print("some error occurred")
except ValueError:
  print("Please enter proper integers")
except:
  print("Some error occurred")
# Out:
# Enter number 1:55
# Enter number 2:gh
# Please enter proper integers

# %% [markdown]
# # catching multiple exceptions in one block.

# %%
try:
  num = int(input("Enter a number:"))
  result = 100 / num
except (ValueError,ZeroDivisionError):
  print("Invalid input.try again")
# Out:
# Enter a number:0
# Invalid input.try again

# %%
try:
  num1 = int(input("Enter number 1:"))
  num2 = int(input("Enter number 2:"))
  print(f"num1/num2 = {num1/num2}")
except Exception as e:
  print(e)
  print(f"Error message = {e}")
# Out:
# Enter number 1:67
# Enter number 2:hj
# invalid literal for int() with base 10: 'hj'
# Error message = invalid literal for int() with base 10: 'hj'

# %% [markdown]
# # Capturing the Exception object.

# %%
try:
  num = int("hello")
except ValueError as e:
  print(f"Caught an error : {e}")
  print(f"Error type: {type(e).__name__}")
# Out:
# Caught an error : invalid literal for int() with base 10: 'hello'
# Error type: ValueError

# %% [markdown]
# # The finally clause

# %%
try:
  f = open("data.txt","r")
  content = f.read()
except FileNotFoundError:
  print("file not found.")
finally:
  print("Cleanup: closing the file.")
  f.close()
# Out:
# file not found.
# Cleanup: closing the file.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5899/1402089652.py in <cell line: 0>()
#       6 finally:
#       7   print("Cleanup: closing the file.")
# ----> 8   f.close()
#
# NameError: name 'f' is not defined

# %% [markdown]
# # try-except-else-finally Toghether.

# %%
try:
  num = int(input("Enter a number:"))
  result = 100/ num
except ValueError:
  print("That's not a valid number.")
except ZeroDivisionError:
  print("You can't divide by zero.")
else:
  print(f"Result: {result}")
finally:
  print("Calculation attempt complete")
# Out:
# Enter a number:67
# Result: 1.492537313432836
# Calculation attempt complete

# %% [markdown]
# # Raising Exceptions : the raise Statement.

# %%
def set_age(age):
  if age < 0:
    raise ValueError("Age cannot be negative.")
  if age > 160:
    raise ValueError("Age seems unrealistic.")
  return age

try:
  set_age(1000)
except ValueError as e:
  print(e)
# Out:
# Age seems unrealistic.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5899/3861776696.py in <cell line: 0>()
#      11   print(e)
#      12
# ---> 13 set_age(-5)
#
# /tmp/ipykernel_5899/3861776696.py in set_age(age)
#       1 def set_age(age):
#       2   if age < 0:
# ----> 3     raise ValueError("Age cannot be negative.")
#       4   if age > 160:
#       5     raise ValueError("Age seems unrealistic.")
#
# ValueError: Age cannot be negative.

# %% [markdown]
# # Custom exception

# %%
class InsufficientFundsError(Exception):
    pass

class Account:
    def __init__(self, name, balance):
        self.name = name
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        return self.balance

    def withdraw(self, amount):
        if amount > self.balance:
            raise InsufficientFundsError("Insufficient funds in the account.")
        self.balance -= amount
        return self.balance
