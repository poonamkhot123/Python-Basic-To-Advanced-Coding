# %% [markdown]
# <a href="https://colab.research.google.com/github/poonamkhot123/Python-Basic-To-Advanced-Coding/blob/main/Day_9_Dictionary_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
marks = {
    "science":99,
    "maths":100,
    "comp":88
    }

# %%
print(marks)
# Out:
# {'science': 99, 'maths': 100, 'comp': 88}

# %%
print(type(marks))
# Out:
# <class 'dict'>

# %%
# key is always immutable.

# %%
# indexing not allowed in dictionary.

# %%
# update
marks["science"]=92

# %%
marks
# Out:
# {'science': 92, 'maths': 100, 'comp': 88}

# %%
marks.update({"city":"Surat"})

# %%
marks
# Out:
# {'science': 92, 'maths': 100, 'comp': 88, 'city': 'Surat'}

# %%
student = {
    "name":"Rahul",
    "age" : 35,
    "gender" : "Male",
    "city" : "Surat"
}

# %%
print(student,id(student))
# Out:
# {'name': 'poonam', 'age': 35, 'gender': 'Male', 'city': 'Surat'} 137566665568512

# %%
student.pop("name")
# Out:
# 'poonam'

# %%
student
# Out:
# {'age': 35, 'gender': 'Male', 'city': 'Surat'}

# %%
student.clear()

# %%
del student

# %%
del student["age"]

# %%
print("age" in student)
# Out:
# True

# %%
k = input("Enter key ==")
if k in student:
  print(student[k])
else:
  print("Key does not exists.")
# Out:
# Enter key ==age
# 35

# %%
k = input("Enter a key:")
if k in student:
  print(student[k])
else:
  print("key does not exists.")
# Out:
# Enter a key:name
# Rahul

# %%
marks = {
    'science':99,
    'maths':100,
    'comp':88,
    'hindi':43,
    'history':71
}

# %%
for k in marks.keys():
  print(k,marks[k])
# Out:
# science 99
# maths 100
# comp 88
# hindi 43
# history 71

# %%
marks.values()
# Out:
# dict_values([99, 100, 88, 43, 71])

# %%
for v in marks.values():
  print(v)
# Out:
# 99
# 100
# 88
# 43
# 71

# %%
print(marks.items())
# Out:
# dict_items([('science', 99), ('maths', 100), ('comp', 88), ('hindi', 43), ('history', 71)])

# %%
for k in marks.items():
  print(k[0])
# Out:
# science
# maths
# comp
# hindi
# history

# %%
for k in marks.items():
  print(k[1])
# Out:
# 99
# 100
# 88
# 43
# 71

# %%
for k,v in marks.items():
  print(k,v)
# Out:
# science 99
# maths 100
# comp 88
# hindi 43
# history 71

# %%
student = {
    'name' : "Rahul",
    'age ': 35,
    'gender' : "Male",
    'city' : "Surat"
}

# %%
student
# Out:
# {'name': 'Rahul', 'age ': 35, 'gender': 'Male', 'city': 'Surat'}

# %%
for k in student.keys():
  print(k)
# Out:
# name
# age
# gender
# city

# %%
for k in student.items():
  print(k)
# Out:
# ('name', 'Rahul')
# ('age ', 35)
# ('gender', 'Male')
# ('city', 'Surat')

# %%
marks = {
    "maths":88,
    "english":76,
    "history":65,
    "computer":95
}

# %%
total_subjects = len(marks)

# %%
print(total_subjects)
# Out:
# 4

# %%
total_marks = sum(marks.values())

# %%
total_marks
# Out:
# 324

# %%
avg = total_marks/total_subjects

# %%
avg
# Out:
# 81.0

# %%
""" populate a dictionary with six student names and their corresponding marks.
Loop through it and print the names of all students who achieved a score above 75."""
# Out:
# ' populate a dictionary with six student names and their corresponding marks.\nLoop through it and print the names of all students who achieved a score above 75.'

# %%
students = {
    "Alice":82,
    "Bob": 67,
    "Charlie":74,
    "Diana":74,
    "Eve":88,
    "Frank":55
}

# %%
for name,mark in students.items():
  if mark>=75:
    print(f"Student = {name},,,, and mark scored = {mark}")
# Out:
# Student = Alice,,,, and mark scored = 82
# Student = Eve,,,, and mark scored = 88

# %%
# Merge Two Dictionaries.
def merge_dicts(dict1,dict2):
  new_dict = {}
  new_dict.update(dict1)
  new_dict.update(dict2)
  return new_dict

# %%
d1 = {"a":1, "b":2, "c":3}
d2 = {"d":4, "e":5, "f":6}

# %%
merge_dicts(d1,d2)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5, 'f': 6}

# %%
len(marks)
# Out:
# 4

# %%
marks.values()
# Out:
# dict_values([88, 76, 65, 95])

# %%
min(marks.values())
# Out:
# 65

# %%
max(marks.values())
# Out:
# 95

# %%
sorted(marks)
# Out:
# ['computer', 'english', 'history', 'maths']

# %% [markdown]
# # Nested Dictionary

# %%
students = {
    '101':{'name':'Rahul',"age":21,"city":"Delhi"},
    '102':{'name':'Priya',"age":20,"city":"mumbai"},
    '103':{'name':"karan","age":22,"city":"Pune"}
}

# %%
print(students['101'])
# Out:
# {'name': 'Rahul', 'age': 21, 'city': 'Delhi'}

# %%
print(students['101']['name'])
# Out:
# Rahul

# %%
print(students['103']['age'])
# Out:
# 22

# %%
for k,v in students.items():
  print(f"k = {k} and v = {v}")
# Out:
# k = 101 and v = {'name': 'Rahul', 'age': 21, 'city': 'Delhi'}
# k = 102 and v = {'name': 'Priya', 'age': 20, 'city': 'mumbai'}
# k = 103 and v = {'name': 'karan', 'age': 22, 'city': 'Pune'}

# %%
students = {
    '101':{'name':'Rahul',"age":21,"city":"Delhi"},
    '102':{'name':'Priya',"age":20,"city":"mumbai"},
    '103':{'name':"karan","age":22,"city":"Pune"}
}

# %%
total = 0
for roll_no,details in students.items():
  total += details['age']
  print(f"roll_no={roll_no},name={details['name']},age={details['age']}")

print(total)
# Out:
# roll_no=101,name=Rahul,age=21
# roll_no=102,name=Priya,age=20
# roll_no=103,name=karan,age=22
# 63
