# %% [markdown]
# <a href="https://colab.research.google.com/github/poonamkhot123/Python-Basic-To-Advanced-Coding/blob/main/Day_3_Arguments_and_Parameters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greet(name):
  print(f"Hello,{name}")

# %%
greet("Poonam")
greet("priya")
# Out:
# Hello,Poonam
# Hello,priya

# %%
def addition(a,b,c):
  ans = a+b+c
  print(f"total = {ans}")

# %%
addition(10,22,67)
# Out:
# total = 99

# %%
def greet(name,age,gender):
  print(f"hey {name}! your age is {age} and gender is {gender}")

  n = input("Enter a nmae =")
  a = int(input("Enter a age"))
  g = input("Enter gender=")

  greet(n,a,g)

# %%
greet("poonam",34,"female")
# Out:
# hey poonam! your age is 34 and gender is female
# Enter a nmae =sahil
# Enter a age21
# Enter gender=male
# hey sahil! your age is 21 and gender is male
# Enter a nmae =mahesh
# Enter a age23
# Enter gender=male
# hey mahesh! your age is 23 and gender is male
# Enter a nmae =shravani
# Enter a age45
# Enter gender=female
# hey shravani! your age is 45 and gender is female
# Enter a nmae =manisha
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2326/70255956.py in <cell line: 0>()
# ----> 1 greet("poonam",34,"female")
#
# /tmp/ipykernel_2326/3811962924.py in greet(name, age, gender)
#       6   g = input("Enter gender=")
#       7
# ----> 8   greet(n,a,g)
#
# /tmp/ipykernel_2326/3811962924.py in greet(name, age, gender)
#       6   g = input("Enter gender=")
#       7
# ----> 8   greet(n,a,g)
#
# /tmp/ipykernel_2326/3811962924.py in greet(name, age, gender)
# ...

# %%
def add(a,b):
  return a+b

# %%
add(5,6)
# Out:
# 11

# %%
def area(length,breadth):
  return length*breadth

# %%
area(23,12)
# Out:
# 276

# %%
def greet(name,age,gender):
  print(f"hey {name}! your age is {age} and gender is {gender}")

# %%
greet("Aniruddha",18,"Male")
# Out:
# hey Aniruddha! your age is 18 and gender is Male

# %%
def greet(name,age,gender):
  print(f"hey {name}! your age is {age} and gender is {gender}")

  n = input("Enter a name:")
  a = int(input("Enter a age:"))
  g = input("Enter gender:")

greet(n,a,g)
# Out:
# hey poonam! your age is 23 and gender is female
# Enter a name:poonam
# Enter a age:23
# Enter gender:female

# %%
def add(n1,n2):
  print(n1+n2)

# %%
add(5,6)
# Out:
# 11

# %%
def find_max(a,b,c):
  if a>b and a>c:
    print(f"{a} is greater number")
  elif b>a and b>c:
    print(f"{b} is greater number")
  else:
    print(f"{c} is greater number")

find_max(6,7,8)
# Out:
# 8 is greater number

# %%
find_max(56,78,95)
# Out:
# 95 is greater number

# %%
# write a function called discount_price that takes original_price and
# discount_percent as parameters and prints the final price after discount.

def discount_price(original_price,dicount_percent):
  discount_amount = (dicount_percent/ 100) * original_price
  final_amount = original_price - discount_amount
  print(f"Your final amount is Rs. {final_amount}")

discount_price(100,50)
# Out:
# Your final amount is Rs. 50.0

# %%
discount_price(100000,58)
# Out:
# Your final amount is Rs. 42000.00000000001

# %%
discount_price(90000,56)
# Out:
# Your final amount is Rs. 39599.99999999999

# %%
def addition(a,b,c):
  return a+b+c
ans = addition(10,20,30)
print(ans)
# Out:
# 60

# %%
def mul(a,b,c):
  return a*b*c
ans = mul(10,20,30)
print(ans)
# Out:
# 6000

# %%
def can_vote(age):
  if age >= 18:
    return True
  else:
    return False

ans = can_vote(20)
print(ans)
# Out:
# True

# %%
def is_prime(num):
  count = 0  # Initialize count here
  for i in range(1, num + 1):
    if num % i == 0:
      count += 1
  # Move return statements outside the loop
  if count == 2:
    return True
  else:
    return False

ans = is_prime(10)
print(ans)
# Out:
# False
