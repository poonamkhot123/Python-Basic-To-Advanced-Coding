# %% [markdown]
# <a href="https://colab.research.google.com/github/poonamkhot123/Python-Basic-To-Advanced-Coding/blob/main/Day_3_conditional_statment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age = int(input("Enter yot age:"))
if age >= 18:
    print("You are eligible to vote")
else:
    print("You are not eligible to vote")

# %%
marks = int(input("Enter a marks:"))
if marks >=90:
  print("Grade A")
elif marks >=80:
  print("Grade :B")
elif marks >=70:
  print("GRade :C")
elif marks >=60:
  print("Grade: D")
else:
  print("Fail")
# Out:
# Enter a marks:98
# Grade A

# %%
def greet():
  print("good morning")
  print("Good afternoon poonam")
  print("Good bye")

# %%
greet()
# Out:
# good morning
# Good afternoon poonam
# Good bye

# %%
# write a function that ask a number from user and prints if that number is odd or even.
def odd_even():
  num=int(input("Enter a number:"))
  if num % 2 == 0:
    print("EVen number")
  else:
    print("odd number.")

# %%
odd_even()
# Out:
# Enter a number:67
# odd number.

# %%
def print_factors():
  num = int(input("Enter a number:"))
  for i in range(1,num+1):
    if num % i ==0:
      print(i,end=" ")

# %%
print_factors()
# Out:
# Enter a number:64
# 1 2 4 8 16 32 64

# %%
def greet(name):
  print(f"hello",{name})
