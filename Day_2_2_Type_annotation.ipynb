# %% [markdown]
# <a href="https://colab.research.google.com/github/poonamkhot123/Python-Basic-To-Advanced-Coding/blob/main/Day_2_2_Type_annotation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# annotations is for us not for python.
def calculate(a:int,b:int) -> int:
  return a + b

print(calculate(1,2))
# Out:
# 3

# %%
def cal_maximum(a:int,b:int,c:int) -> None:
  print(f"Maximum of a,b,c is {max(a,b,c)}")

cal_maximum(1,2,3)
# Out:
# Maximum of a,b,c is 3

# %%
def greet(name:str,age:int,marks:float,adult:bool):
  pass

# %%
def max_marks(marks:list[int]) -> int:
  return max(marks)

ans = max_marks([65,32,67,87,33])
print(ans)
# Out:
# 87

# %%
def print_list(lst:list[int | str]):
  print(lst)

# %%
ans = max_marks([65,32,67,87,33])
print(ans)
print_list([43,54,34,26,67])
# Out:
# 87
# [43, 54, 34, 26, 67]

# %%
# for only annotation we can use.
from typing import List
