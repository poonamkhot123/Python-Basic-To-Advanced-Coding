# %% [markdown]
# <a href="https://colab.research.google.com/github/poonamkhot123/Python-Basic-To-Advanced-Coding/blob/main/Python_Fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("poonam","khot",sep=" *")
# Out:
# poonam *khot

# %%
print("hello")
print("world")
# Out:
# hello
# world

# %%
print("hello",end = "-")
print("world")
# Out:
# hello-world

# %% [markdown]
# # Data types

# %%
# integer
print(8)
# 1* 10^308
print(1e309)
# Out:
# 8
# inf

# %%
# complex
print(5+6j)
# Out:
# (5+6j)

# %%
# 8976689766

# %%
Data types
int
boolean
list
string
tuple
set
dictionary

# %%
# what is dynamic typing.
# what is static typing.
# what is dynamic binding
# what is static binding

# %%
a = 3
b = 4
c = 5
print(a,b,c)
# Out:
# 3 4 5

# %%
a,b,c = 2,3,4
print(a,b,c)
# Out:
# 2 3 4

# %%
# what is compilation.
# compiler
# interpreter

# %%
# keywords and identifiers

# %%
str(5)
# Out:
# '5'

# %%
float(4)
# Out:
# 4.0

# %%
a = int(input("Enter a No."))
b = int(input("Enter a no."))
sum= a+b
print(sum)
# Out:
# Enter a No.45
# Enter a no56
# 101

# %% [markdown]
# # Literals

# %%
a = 0b1010 #Binary Literals
b = 100 #Decimal literal
c = 0o310 #Octal Literal
d = 0x12c #Hexadecimal Literal

# Float literal
float_1 = 10.5
float_2 = 1.5e2
float_3 = 1.5e-3

# Complex literal
x = 3.14j

# binary
a = 0b1010

print(a,b,c,d)
# Out:
# 10 100 200 300

# %%
a = None
print(a)
# Out:
# None

# %%
a = 5
b = 6
print(a+b)
# Out:
# 11

# %%
k = None
a = 5
b = 6
print("Program exe")
# Out:
# Program exe
