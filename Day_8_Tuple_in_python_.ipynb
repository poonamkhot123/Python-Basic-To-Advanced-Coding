# %% [markdown]
# <a href="https://colab.research.google.com/github/poonamkhot123/Python-Basic-To-Advanced-Coding/blob/main/Day_8_Tuple_in_python_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
t = (1,2,3,4,"poonam")

# %%
print(t)
# Out:
# (1, 2, 3, 4, 'poonam')

# %%
print(type(t))
# Out:
# <class 'tuple'>

# %%
# tuple is immutable.

# %%
t.count(1)
# Out:
# 1

# %%
print(t[0:2])
# Out:
# (1, 2)

# %%
print(t[::-1])
# Out:
# ('poonam', 4, 3, 2, 1)

# %%
t
# Out:
# (1, 2, 3, 4, 'poonam')

# %% [markdown]
# # Iterations

# %%
t = (45,32,11,"poonam",'Khurana',"surat",99)
n = len(t)
for i in range(0,n):
  print(t[i],end = " ")
print()
# Out:
# 45 32 11 poonam Khurana surat 99

# %%
print(len(t))
# Out:
# 7

# %%
list = [3,4,5,6]
my_tuple = tuple(list)
print(my_tuple)
# Out:
# (3, 4, 5, 6)

# %% [markdown]
# # Tuple Packing and Unpacking.

# %%
a,b,c,d = 1,2,3,4

# %%
print(a,type(a))
# Out:
# 1 <class 'int'>

# %%
print(b,type(b))
# Out:
# 2 <class 'int'>

# %%
print(c,type(c))
# Out:
# 3 <class 'int'>

# %%
print(d,type(d))
# Out:
# 4 <class 'int'>

# %%
a,b = 4,5
