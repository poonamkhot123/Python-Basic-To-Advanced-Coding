# %% [markdown]
# <a href="https://colab.research.google.com/github/poonamkhot123/Python-Basic-To-Advanced-Coding/blob/main/Day_2_Python_full_course.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Eascape Sequences
#  * An escape sequence is a special character that starts with a backslash \ it lets you put things inside a string that are otherwise hard to type directly.

# %% [markdown]
# ![Screenshot 2026-07-03 191040.png](data:image/png;base64,...)

# %%
print("hello")
print("world")
# Out:
# hello
# world

# %%
print("hello\n world")
# Out:
# hello
#  world

# %%
print("hello\tworld")
# Out:
# hello	world

# %%
print("A\\niruddha")
# Out:
# A\niruddha

# %%
print('my name is \'aniruddha\' khurana')
# Out:
# my name is 'aniruddha' khurana

# %% [markdown]
# # operators

# %%
a = -29
b = 10
print(a+b)
# Out:
# 39

# %%
print(a-b)
# Out:
# -5

# %%
print(a*b)
# Out:
# 50

# %%
print(a / b)
# Out:
# 2.9

# %%
# Floor division
print(a//b)
# Out:
# 2

# %%
print(b//a)
# Out:
# 0

# %%
# Exponent
print(2**5)
# Out:
# 32

# %%
print(100**0.5)
# Out:
# 10.0

# %% [markdown]
# # Operator precedence

# %%
print(2+3*4)
# Out:
# 14

# %%
print(10-2**3)
# Out:
# 2

# %%
print(10 // 2 + 3)
# Out:
# 8

# %%
# use parentheses to force the order you want.
print((2+3)*4)
print((10-2)*3)
# Out:
# 20
# 24

# %% [markdown]
# # Comparison Operators.

# %%
a = 10
b = 5

# %%
print(a==b)
# Out:
# False

# %%
print (a>b)
# Out:
# True

# %%
print(a<b)
# Out:
# False

# %%
print(a>=b)
# Out:
# True

# %%
print(a<=b)
# Out:
# False

# %%
print(a!=b)
# Out:
# True

# %% [markdown]
# # Logical Operators

# %%
chemistry = 45
physics = 34
print(chemistry > 33 and physics > 30)
# Out:
# True

# %%
print(chemistry < 33 or physics > 50)
# Out:
# False

# %%
print(not(chemistry > 33 and physics > 30))
# Out:
# False

# %%
a  = int(input("Enter a number:"))
if a % 2 == 0:
  print("number is even")
else:
  print("number is odd")
# Out:
# Enter a number:5
# number is odd

# %%
a = int(input("Enter a age:"))
if a >=18:
  print("you are eligible to vote.")
else:
  print("you are not eligible to vote.")
# Out:
# Enter a age:67
# you are eligible to vote.

# %%
a = int(input("Enter a marks of physics:"))
b = int(input("Enter a marks of chemistry:"))
c = int(input("Enter a marks of math:"))

total = a + b +c

print(total)

print(total/3)
# Out:
# Enter a marks of physics:45
# Enter a marks of chemistry:67
# Enter a marks of math:50
# 162
# 54.0
